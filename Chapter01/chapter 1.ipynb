# %% [markdown]
# ### Chapter 1

# %%
def add(a,b):
    c = a +  b
    return c

# %% [markdown]
# #### Scenario 1:

# %%
add(1,3)
# Out:
# 4

# %% [markdown]
# #### Scenario 2:

# %%
add('meta','program')
# Out:
# 'metaprogram'

# %% [markdown]
# #### Scenario 3:

# %%
add('meta',1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f8ebbea09bb2> in <module>
# ----> 1 add('meta',1)
#
# <ipython-input-1-1228376a5862> in add(a, b)
#       1 def add(a,b):
# ----> 2     c = a +  b
#       3     return c
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #### Metadata of the function add

# %%
def add(a,b):
    c = a +  b
    print ("Metadata of add", type(add))
    print ("Metadata of a", type(a))
    print ("Metadata of b", type(b))
    print ("Metadata of c", type(c))

# %%
add(1,3)
# Out:
# Metadata of add <class 'function'>
# Metadata of a <class 'int'>
# Metadata of b <class 'int'>
# Metadata of c <class 'int'>

# %%
add('test','string')
# Out:
# Metadata of add <class 'function'>
# Metadata of a <class 'str'>
# Metadata of b <class 'str'>
# Metadata of c <class 'str'>

# %% [markdown]
# ### Solve using metaprogramming

# %% [markdown]
# #### Scenario 1

# %%
def add(a,b):
    checkint = 1
    checkstr = 'test'
    if (type(a) is type(checkstr) and type(b) is type(checkint)) or\
        (type(a) is type(checkint) and type(b) is type(checkstr)):
        return "Please enter both input values as integers or string"
    else:
        c = a + b
        return c

# %%
add(1,3)
# Out:
# 4

# %%
add('meta','program')
# Out:
# 'metaprogram'

# %%
add('meta',1)
# Out:
# 'Please enter both input values as integers or string'

# %%
add(1,'meta')
# Out:
# 'Please enter both input values as integers or string'

# %% [markdown]
# #### Scenario 2

# %%
def add(a,b):
    if type(a) is int and type(b) is int:
        c = a +  b
        return c
    elif type(a) is str and type(b) is int or\
          type(a) is int and type(b) is str or \
          type(a) is str and type(b) is str:
        c = str(a) + str(b)
        return c
    else:
        print("Please enter string or integer")

# %%
add(1343,35789)
# Out:
# 37132

# %%
add('Meta','Programming')
# Out:
# 'MetaProgramming'

# %%
add('meta',157676)
# Out:
# 'meta157676'

# %%
add(65081, 'meta')
# Out:
# '65081meta'

# %%
add(True, 'meta')
# Out:
# Please enter string or integer

# %% [markdown]
# #### Scenario 3

# %%
def add(a,b):
    if type(a) is int and type(b) is int or\
       type(a) is float and type(b) is float or\
       type(a) is int and type(b) is float or\
       type(a) is float and type(b) is int:
        c = a +  b
        return c
    else:
        return 'Please input numbers'

# %%
add(15443,675683)
# Out:
# 691126

# %%
add(54381,3.7876)
# Out:
# 54384.7876

# %%
add(6.7754,543.76)
# Out:
# 550.5354

# %%
add(79894,0.6568)
# Out:
# 79894.6568

# %%
add('meta',14684)
# Out:
# 'Please input numbers'

# %%
add(6576,'meta')
# Out:
# 'Please input numbers'

# %%
add('meta','program')
# Out:
# 'Please input numbers'

# %% [markdown]
# ### Don't Repeat Yourself

# %%
def add(a,b):
    c = a + b
    return c

def sub(a,b):
    c = a - b
    return c

def multiply(a,b):
    c = a * b
    return c

def divide(a,b):
    c = a / b
    return c

# %%
add(2,5)
# Out:
# 7

# %%
sub(2,5)
# Out:
# -3

# %%
multiply(2,5)
# Out:
# 10

# %%
divide(2,5)
# Out:
# 0.4

# %% [markdown]
# ### Alternative approach

# %%
import operator as op

# %%
def arithmetic(a, b, operation):
    result = operation(a, b)
    return result

# %%
arithmetic('2', '5', op.add)
# Out:
# '25'

# %%
arithmetic(2, 5, op.add)
# Out:
# 7

# %%
arithmetic(2 , 5, op.sub)
# Out:
# -3

# %%
arithmetic(2, 5, op.mul)
# Out:
# 10

# %%
arithmetic(2 , 5, op.truediv)
# Out:
# 0.4

# %% [markdown]
# ### Dynamic Function Creation

# %%
from types import FunctionType

# %%
functionstring = '''
def arithmetic(a, b):
    op = __import__('operator')
    result = op.add(a, b)
    return result
    '''

# %%
print(functionstring)
# Out:
# def arithmetic(a, b):
#     op = __import__('operator')
#     result = op.add(a, b)
#     return result

# %%
functiontemplate = compile(functionstring, 'functionstring', 'exec')

# %%
functiontemplate
# Out:
# <code object <module> at 0x000001DFBF15D5B0, file "functionstring", line 2>

# %%
functiontemplate.co_consts[0]
# Out:
# <code object arithmetic at 0x000001DFBF15D500, file "functionstring", line 2>

# %%
dynamicfunction = FunctionType(functiontemplate.co_consts[0], globals(), "add")

# %%
dynamicfunction
# Out:
# <function __main__.arithmetic(a, b)>

# %%
dynamicfunction(2,5)
# Out:
# 7

# %%
a = 2
b = 5

operator = ['op.add','op.sub','op.mul','op.truediv','op.pow','op.mod', 'op.gt', 'op.lt']
functionname = ['add','sub', 'multiply', 'divide', 'power', 'modulus', 'greaterthan', 'lesserthan']

def functiongenerator(functionname, operator, a,b):
    from types import FunctionType
    functionstring = []
    for i in operator:
        functionstring.append('''
def arithmetic(a, b):
    op = __import__('operator')
    result = '''+ i + '''(a, b)
    return result
    ''')

    functiontemplate = []
    for i in functionstring:
        functiontemplate.append(compile(i, 'functionstring', 'exec'))

    dynamicfunction = []
    for i,j in zip(functiontemplate,functionname):
        dynamicfunction.append(FunctionType(i.co_consts[0], globals(), j))

    functiondict = {}
    
    for i,j in zip(functionname,dynamicfunction):
        functiondict[i]=j
        
    for i in dynamicfunction:
        print (i(a,b))
    
    return functiondict

# %%
funcdict = functiongenerator(functionname, operator, a,b)
# Out:
# 7
# -3
# 10
# 0.4
# 32
# 2
# False
# True

# %%
funcdict
# Out:
# {'add': <function __main__.arithmetic(a, b)>,
#  'sub': <function __main__.arithmetic(a, b)>,
#  'multiply': <function __main__.arithmetic(a, b)>,
#  'divide': <function __main__.arithmetic(a, b)>,
#  'power': <function __main__.arithmetic(a, b)>,
#  'modulus': <function __main__.arithmetic(a, b)>,
#  'greaterthan': <function __main__.arithmetic(a, b)>,
#  'lesserthan': <function __main__.arithmetic(a, b)>}

# %%
funcdict['divide'](a,b)
# Out:
# 0.4

# %%
funcdict['lesserthan'](a,b)
# Out:
# True

# %%
funcdict['greaterthan'](a,b)
# Out:
# False

# %% [markdown]
# ### These are all the examples covered in chapter 1
